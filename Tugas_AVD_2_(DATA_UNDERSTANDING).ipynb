# %% [markdown]
# <a href="https://colab.research.google.com/github/ainunnnnnn23/AVD/blob/main/Tugas_AVD_2_(DATA_UNDERSTANDING).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **DATA UNDERSTANDING**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
dataset_url = "https://www.kaggle.com/datasets/your-dataset-link"
print(f"Dataset yang digunakan: {dataset_url}")
# Out:
# Dataset yang digunakan: https://www.kaggle.com/datasets/your-dataset-link

# %%
import pandas as pd

# %%
file_path = "/content/most_used_beauty_cosmetics_products_extended.csv"
df = pd.read_csv(file_path)
df.head()
# Out:
#        Product_Name              Brand        Category Usage_Frequency  \
# 0   Ultra Face Mask     Drunk Elephant           Blush          Weekly
# 1    Ultra Lipstick      Laura Mercier  Makeup Remover      Occasional
# 2       Ultra Serum     Natasha Denona     Highlighter           Daily
# 3      Divine Serum        Ilia Beauty       Face Mask      Occasional
# 4  Super Foundation  Charlotte Tilbury     Highlighter      Occasional
#
#    Price_USD  Rating  Number_of_Reviews Product_Size  Skin_Type Gender_Target  \
# 0      67.85     1.4                686         30ml  Sensitive        Female
# 1     116.43     4.2               5483        250ml        Dry        Unisex
# 2      90.84     1.6               5039        100ml  Sensitive          Male
# 3      55.17     3.2               6202        250ml     Normal          Male
# 4     140.56     1.7                297        100ml       Oily        Female
#
#   Packaging_Type Main_Ingredient  Cruelty_Free Country_of_Origin
# ...

# %%
df.head()
# Out:
#        Product_Name              Brand        Category Usage_Frequency  \
# 0   Ultra Face Mask     Drunk Elephant           Blush          Weekly
# 1    Ultra Lipstick      Laura Mercier  Makeup Remover      Occasional
# 2       Ultra Serum     Natasha Denona     Highlighter           Daily
# 3      Divine Serum        Ilia Beauty       Face Mask      Occasional
# 4  Super Foundation  Charlotte Tilbury     Highlighter      Occasional
#
#    Price_USD  Rating  Number_of_Reviews Product_Size  Skin_Type Gender_Target  \
# 0      67.85     1.4                686         30ml  Sensitive        Female
# 1     116.43     4.2               5483        250ml        Dry        Unisex
# 2      90.84     1.6               5039        100ml  Sensitive          Male
# 3      55.17     3.2               6202        250ml     Normal          Male
# 4     140.56     1.7                297        100ml       Oily        Female
#
#   Packaging_Type Main_Ingredient  Cruelty_Free Country_of_Origin
# ...

# %%
df.tail()
# Out:
#            Product_Name         Brand     Category Usage_Frequency  Price_USD  \
# 14995    Magic Eyeliner    Patrick Ta    Face Mask           Daily     131.64
# 14996    Perfect Powder       Farsali        Serum          Weekly      76.35
# 14997       Magic Serum       Kiehl’s  Highlighter      Occasional      65.37
# 14998     Magic Mascara  Perricone MD       Powder          Weekly      59.93
# 14999  Divine Lip Liner        Tatcha        Blush           Daily      36.96
#
#        Rating  Number_of_Reviews Product_Size    Skin_Type Gender_Target  \
# 14995     2.8               1470        250ml    Sensitive        Unisex
# 14996     2.1               7652        250ml          Dry        Unisex
# 14997     4.2                811         30ml  Combination        Unisex
# 14998     4.8               5482        250ml          Dry          Male
# 14999     1.1               5452        200ml       Normal        Female
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15000 entries, 0 to 14999
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Product_Name       15000 non-null  object
#  1   Brand              15000 non-null  object
#  2   Category           15000 non-null  object
#  3   Usage_Frequency    15000 non-null  object
#  4   Price_USD          15000 non-null  float64
#  5   Rating             15000 non-null  float64
#  6   Number_of_Reviews  15000 non-null  int64
#  7   Product_Size       15000 non-null  object
#  8   Skin_Type          15000 non-null  object
#  9   Gender_Target      15000 non-null  object
#  10  Packaging_Type     15000 non-null  object
#  11  Main_Ingredient    15000 non-null  object
#  12  Cruelty_Free       15000 non-null  bool
#  13  Country_of_Origin  15000 non-null  object
# dtypes: bool(1), float64(2), int64(1), object(10)
# memory usage: 1.5+ MB

# %%
df.shape
# Out:
# (15000, 14)

# %%
df.dtypes
# Out:
# Product_Name          object
# Brand                 object
# Category              object
# Usage_Frequency       object
# Price_USD            float64
# Rating               float64
# Number_of_Reviews      int64
# Product_Size          object
# Skin_Type             object
# Gender_Target         object
# Packaging_Type        object
# Main_Ingredient       object
# Cruelty_Free            bool
# Country_of_Origin     object
# dtype: object

# %%
df.describe()
# Out:
#           Price_USD        Rating  Number_of_Reviews
# count  15000.000000  15000.000000       15000.000000
# mean      80.134108      3.002327        5014.231333
# std       40.402983      1.168029        2855.665464
# min       10.000000      1.000000          52.000000
# 25%       45.480000      2.000000        2562.000000
# 50%       80.040000      3.000000        5002.000000
# 75%      114.760000      4.000000        7497.000000
# max      149.990000      5.000000       10000.000000

# %%
df.value_counts()
# Out:
# Product_Name         Brand                    Category       Usage_Frequency  Price_USD  Rating  Number_of_Reviews  Product_Size  Skin_Type  Gender_Target  Packaging_Type  Main_Ingredient  Cruelty_Free  Country_of_Origin
# Divine BB Cream      Anastasia Beverly Hills  Face Mask      Weekly           87.14      1.5     1337               250ml         Sensitive  Unisex         Spray           Hyaluronic Acid  True          Australia            1
# Super Exfoliator     Shiseido                 Powder         Weekly           47.16      3.2     1940               250ml         Oily       Unisex         Spray           Glycerin         False         Japan                1
#                      Pat McGrath Labs         Serum          Monthly          26.17      4.5     5633               150ml         Sensitive  Female         Jar             Retinol          False         Japan                1
# ...

# %%
df.select_dtypes(include=['number']).mean()
# Out:
# Price_USD              80.134108
# Rating                  3.002327
# Number_of_Reviews    5014.231333
# dtype: float64

# %%
df.select_dtypes(include=['number']).corr()
# Out:
#                    Price_USD    Rating  Number_of_Reviews
# Price_USD           1.000000 -0.005232          -0.005567
# Rating             -0.005232  1.000000          -0.002428
# Number_of_Reviews  -0.005567 -0.002428           1.000000
