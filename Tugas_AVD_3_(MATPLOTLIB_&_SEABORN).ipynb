# %% [markdown]
# <a href="https://colab.research.google.com/github/ainunnnnnn23/AVD/blob/main/Tugas_AVD_3_(MATPLOTLIB_%26_SEABORN).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("/content/most_used_beauty_cosmetics_products_extended.csv")
df_selected = df.copy()
df_top100 = df.head(100) #mennggunakan 100 data teratas
df
# Out:
#            Product_Name              Brand        Category Usage_Frequency  \
# 0       Ultra Face Mask     Drunk Elephant           Blush          Weekly
# 1        Ultra Lipstick      Laura Mercier  Makeup Remover      Occasional
# 2           Ultra Serum     Natasha Denona     Highlighter           Daily
# 3          Divine Serum        Ilia Beauty       Face Mask      Occasional
# 4      Super Foundation  Charlotte Tilbury     Highlighter      Occasional
# ...                 ...                ...             ...             ...
# 14995    Magic Eyeliner         Patrick Ta       Face Mask           Daily
# 14996    Perfect Powder            Farsali           Serum          Weekly
# 14997       Magic Serum            Kiehl’s     Highlighter      Occasional
# 14998     Magic Mascara       Perricone MD          Powder          Weekly
# 14999  Divine Lip Liner             Tatcha           Blush           Daily
#
# ...

# %%
plt.figure(figsize=(8, 5))
sns.histplot(df_top100['Rating'], bins=100, kde=True, color='skyblue')
plt.title("Distribusi Rating Produk Kosmetik (Top 100)")
plt.xlabel("Rating")
plt.ylabel("Jumlah Produk")
plt.show()

# %% [markdown]
# **Berikut adalah visualisasi distribusi rating produk kosmetik, dan insight yang dapat diambil yaitu:**
#
# Sebagian besar produk memiliki rating tinggi di sekitar 4 hingga 5.
#
# Produk dengan rating rendah lebih jarang ditemukan, namun tetap ada.
#
# Distribusi ini menunjukkan bahwa kebanyakan produk kosmetik memiliki kualitas yang cukup baik di mata konsumen.

# %%
plt.figure(figsize=(12, 6))
category_avg_rating = df_top10.groupby("Category")["Rating"].mean().sort_values(ascending=False)
sns.barplot(x=category_avg_rating.index, y=category_avg_rating.values, palette="magma")
plt.xticks(rotation=45, ha="right")
plt.title("Rata-rata Rating Berdasarkan Kategori Produk (Top 100)")
plt.xlabel("Kategori Produk")
plt.ylabel("Rata-rata Rating")
plt.show()
# Out:
# <ipython-input-12-5ac912fe10cc>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=category_avg_rating.index, y=category_avg_rating.values, palette="magma")

# %% [markdown]
# Produk dengan kategori Contour, Moisturizer, dan CC Cream memiliki rata-rata rating tertinggi, Ini menunjukkan bahwa konsumen cenderung lebih puas dengan produk dari kategori ini, Kategori seperti Lip Liner dan Eyeliner memiliki rata-rata rating lebih rendah dibanding kategori lainnya, Ini bisa menjadi peluang bagi brand kosmetik untuk meningkatkan kualitas atau strategi pemasaran produk dalam kategori ini.

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x=df_top100["Price_USD"], y=df_top100["Rating"], alpha=0.5, color="purple")
plt.title("Hubungan antara Harga dan Rating Produk (Top 100)")
plt.xlabel("Harga (USD)")
plt.ylabel("Rating")
plt.xscale("log")  # Menggunakan skala log untuk harga agar lebih terbaca
plt.show()

# %% [markdown]
# **Visualisasi hubungan antara harga dan rating produk kosmetik:**
#
# Tidak terlihat korelasi yang jelas antara harga dan rating. Produk dengan harga tinggi maupun rendah memiliki variasi rating yang serupa.
# Hal ini menunjukkan bahwa faktor lain, seperti kualitas bahan, merek, atau ulasan pengguna, mungkin lebih berpengaruh terhadap rating dibandingkan harga.
# Produk dengan harga lebih tinggi tidak selalu mendapatkan rating lebih baik, yang bisa menjadi indikasi bahwa konsumen menilai produk berdasarkan pengalaman penggunaan, bukan sekadar harga.

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x=df_top100["Number_of_Reviews"], y=df_top100["Rating"], alpha=0.6, color="blue")
plt.title("Hubungan antara Jumlah Ulasan dan Rating Produk (Top 100)")
plt.xlabel("Jumlah Ulasan")
plt.ylabel("Rating")
plt.xscale("log")  # Menggunakan skala log agar distribusi lebih jelas
plt.show()

# %% [markdown]
# **Visualisasi hubungan antara jumlah ulasan dan rating produk kosmetik:**
#
# Produk dengan rating tinggi cenderung memiliki lebih banyak ulasan, menunjukkan bahwa produk yang disukai konsumen lebih sering mendapatkan perhatian dan feedback.
# Namun, ada juga beberapa produk dengan jumlah ulasan tinggi tetapi memiliki rating rendah, yang bisa mengindikasikan pengalaman negatif pengguna.
# Sebagian besar produk dengan rating rendah memiliki jumlah ulasan yang lebih sedikit, yang mungkin menunjukkan kurangnya popularitas atau ketertarikan dari konsumen.

# %% [markdown]
# **Kesimpulan:**
#
# **Kategori Produk dengan Rating Tertinggi:**
# Produk dalam kategori Contour, Moisturizer, dan CC Cream memiliki rata-rata rating tertinggi.
# Sebaliknya, kategori seperti Lip Liner dan Eyeliner memiliki rating lebih rendah, yang bisa menjadi peluang perbaikan bagi produsen.
#
# **Hubungan Harga dengan Rating:** Tidak ada hubungan yang jelas antara harga dan rating.
# Produk mahal tidak selalu mendapatkan rating lebih tinggi, menunjukkan bahwa faktor lain seperti kualitas dan pengalaman pengguna lebih berpengaruh.
#
# **Hubungan Jumlah Ulasan dengan Rating:** Produk dengan rating tinggi cenderung memiliki lebih banyak ulasan, menandakan tingkat kepuasan yang baik dan kepercayaan konsumen.
# Sebaliknya, beberapa produk dengan banyak ulasan memiliki rating rendah, yang bisa mengindikasikan banyak keluhan dari pengguna.

# %% [markdown]
# **Rekomendasi:**
#
# Fokus pada kategori dengan rating rendah, seperti Lip Liner dan Eyeliner, untuk meningkatkan kualitas produk atau strategi pemasaran.
# Optimalkan strategi harga, karena harga bukan faktor utama dalam penilaian pelanggan. Sebaiknya, produsen fokus pada bahan, formula, dan manfaat produk.
# Dorong ulasan pelanggan positif dengan cara memberikan insentif atau program loyalitas, karena lebih banyak ulasan positif dapat meningkatkan kepercayaan konsumen terhadap produk.
# Perbaiki produk dengan banyak ulasan tapi rating rendah, dengan melakukan survei terhadap pelanggan untuk memahami aspek yang perlu diperbaiki.
