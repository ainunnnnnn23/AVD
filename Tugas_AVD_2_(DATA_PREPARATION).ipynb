# %% [markdown]
# <a href="https://colab.research.google.com/github/ainunnnnnn23/AVD/blob/main/Tugas_AVD_2_(DATA_PREPARATION).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv("/content/most_used_beauty_cosmetics_products_extended.csv")
df
# Out:
#            Product_Name              Brand        Category Usage_Frequency  \
# 0       Ultra Face Mask     Drunk Elephant           Blush          Weekly
# 1        Ultra Lipstick      Laura Mercier  Makeup Remover      Occasional
# 2           Ultra Serum     Natasha Denona     Highlighter           Daily
# 3          Divine Serum        Ilia Beauty       Face Mask      Occasional
# 4      Super Foundation  Charlotte Tilbury     Highlighter      Occasional
# ...                 ...                ...             ...             ...
# 14995    Magic Eyeliner         Patrick Ta       Face Mask           Daily
# 14996    Perfect Powder            Farsali           Serum          Weekly
# 14997       Magic Serum            Kiehl’s     Highlighter      Occasional
# 14998     Magic Mascara       Perricone MD          Powder          Weekly
# 14999  Divine Lip Liner             Tatcha           Blush           Daily
#
# ...

# %% [markdown]
# **DATA CLEANING**

# %%
print((df.isna().sum() / len(df)) * 100)
# Out:
# Product_Name         0.0
# Brand                0.0
# Category             0.0
# Usage_Frequency      0.0
# Price_USD            0.0
# Rating               0.0
# Number_of_Reviews    0.0
# Product_Size         0.0
# Skin_Type            0.0
# Gender_Target        0.0
# Packaging_Type       0.0
# Main_Ingredient      0.0
# Cruelty_Free         0.0
# Country_of_Origin    0.0
# dtype: float64

# %%
pd.DataFrame(df.isna().sum() / len(df) * 100, columns=['Null Ratio %'])
# Out:
#                    Null Ratio %
# Product_Name                0.0
# Brand                       0.0
# Category                    0.0
# Usage_Frequency             0.0
# Price_USD                   0.0
# Rating                      0.0
# Number_of_Reviews           0.0
# Product_Size                0.0
# Skin_Type                   0.0
# Gender_Target               0.0
# Packaging_Type              0.0
# Main_Ingredient             0.0
# Cruelty_Free                0.0
# Country_of_Origin           0.0

# %% [markdown]
# **Duplicated Values**

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Product_Name, Brand, Category, Usage_Frequency, Price_USD, Rating, Number_of_Reviews, Product_Size, Skin_Type, Gender_Target, Packaging_Type, Main_Ingredient, Cruelty_Free, Country_of_Origin]
# Index: []

# %% [markdown]
# **Outliers**

# %%
results = []

cols = df.select_dtypes(include=['float64', 'int64'])

for col in cols:
  q1 = df[col].quantile(0.25)
  q3 = df[col].quantile(0.75)
  iqr = q3 - q1
  lower_bound = q1 - 1.5*iqr
  upper_bound = q3 + 1.5*iqr
  outliers = df[(df[col] < lower_bound) | (df[col] > upper_bound)]
  percent_outliers = (len(outliers)/len(df))*100
  results.append({'Kolom': col, 'Persentase Outliers': percent_outliers})

# Dataframe dari list hasil
results_df = pd.DataFrame(results)
results_df.set_index('Kolom', inplace=True)
results_df = results_df.rename_axis(None, axis=0).rename_axis('Kolom', axis=1)

# Tampilkan dataframe
display(results_df)
# Out:
# Kolom              Persentase Outliers
# Price_USD                          0.0
# Rating                             0.0
# Number_of_Reviews                  0.0

# %%
df
# Out:
#            Product_Name              Brand        Category Usage_Frequency  \
# 0       Ultra Face Mask     Drunk Elephant           Blush          Weekly
# 1        Ultra Lipstick      Laura Mercier  Makeup Remover      Occasional
# 2           Ultra Serum     Natasha Denona     Highlighter           Daily
# 3          Divine Serum        Ilia Beauty       Face Mask      Occasional
# 4      Super Foundation  Charlotte Tilbury     Highlighter      Occasional
# ...                 ...                ...             ...             ...
# 14995    Magic Eyeliner         Patrick Ta       Face Mask           Daily
# 14996    Perfect Powder            Farsali           Serum          Weekly
# 14997       Magic Serum            Kiehl’s     Highlighter      Occasional
# 14998     Magic Mascara       Perricone MD          Powder          Weekly
# 14999  Divine Lip Liner             Tatcha           Blush           Daily
#
# ...

# %% [markdown]
# **Inconsistent Values**
#
# Tidak memiliki nilai inconsistent

# %% [markdown]
# **Contruct Data**

# %%
def categorize_price(price):
    if price < 10:
        return "Cheap"
    elif 10 <= price <= 30:
        return "Medium"
    else:
        return "Expensive"

df["Price_Category"] = df["Price_USD"].apply(categorize_price)

# %%
df
# Out:
#            Product_Name              Brand        Category Usage_Frequency  \
# 1       Ultra Face Mask     Drunk Elephant           Blush          Weekly
# 2        Ultra Lipstick      Laura Mercier  Makeup Remover      Occasional
# 3           Ultra Serum     Natasha Denona     Highlighter           Daily
# 4          Divine Serum        Ilia Beauty       Face Mask      Occasional
# 5      Super Foundation  Charlotte Tilbury     Highlighter      Occasional
# ...                 ...                ...             ...             ...
# 14996    Magic Eyeliner         Patrick Ta       Face Mask           Daily
# 14997    Perfect Powder            Farsali           Serum          Weekly
# 14998       Magic Serum            Kiehl’s     Highlighter      Occasional
# 14999     Magic Mascara       Perricone MD          Powder          Weekly
# 15000  Divine Lip Liner             Tatcha           Blush           Daily
#
# ...

# %% [markdown]
# **Data Reduction**

# %%
df = df.drop('Number_of_Reviews', axis=1)

# %%
df
# Out:
#            Product_Name              Brand        Category Usage_Frequency  \
# 1       Ultra Face Mask     Drunk Elephant           Blush          Weekly
# 2        Ultra Lipstick      Laura Mercier  Makeup Remover      Occasional
# 3           Ultra Serum     Natasha Denona     Highlighter           Daily
# 4          Divine Serum        Ilia Beauty       Face Mask      Occasional
# 5      Super Foundation  Charlotte Tilbury     Highlighter      Occasional
# ...                 ...                ...             ...             ...
# 14996    Magic Eyeliner         Patrick Ta       Face Mask           Daily
# 14997    Perfect Powder            Farsali           Serum          Weekly
# 14998       Magic Serum            Kiehl’s     Highlighter      Occasional
# 14999     Magic Mascara       Perricone MD          Powder          Weekly
# 15000  Divine Lip Liner             Tatcha           Blush           Daily
#
#        Price_USD  Rating Product_Size    Skin_Type Gender_Target  \
# ...
